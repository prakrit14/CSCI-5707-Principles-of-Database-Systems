# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df=pd.read_csv('msp_Crime_Data.csv')

# %%
df.head()
# Out:
#            X          Y                      Type Case_Number Case_NumberAlt  \
# 0 -93.305062  44.998752  Additional Crime Metrics   19-009342     MP20199342
# 1 -93.311416  44.995151  Additional Crime Metrics   19-013520    MP201913520
# 2 -93.290539  44.961813  Additional Crime Metrics   19-025082    MP201925082
# 3 -93.291154  45.007731  Additional Crime Metrics   19-030820    MP201930820
# 4 -93.258524  44.894316  Additional Crime Metrics   19-033021    MP201933021
#
#             Reported_Date           Occurred_Date NIBRS_Crime_Against  \
# 0  2019/01/10 13:00:00+00  2019/01/09 23:00:00+00      Non NIBRS Data
# 1  2019/01/14 17:42:00+00  2019/01/14 17:18:00+00      Non NIBRS Data
# 2  2019/01/26 14:15:00+00  2019/01/26 12:00:00+00      Non NIBRS Data
# 3  2019/02/01 16:39:00+00  2019/02/01 15:22:00+00      Non NIBRS Data
# 4  2019/02/03 23:12:00+00  2019/02/03 23:12:00+00      Non NIBRS Data
#
#       NIBRS_Group      NIBRS_Code                  Offense_Category  \
# ...

# %%
df['Neighborhood'].unique()
# Out:
# array(['Willard - Hay', 'Lowry Hill East', 'Hawthorne', 'Diamond Lake',
#        'Whittier', 'Beltrami', 'Sumner - Glenwood', 'Midtown Phillips',
#        'Longfellow', 'Webber - Camden', 'Ventura Village', 'Standish',
#        'Jordan', 'Marcy Holmes', 'Loring Park', 'West Maka Ska',
#        'Near - North', 'Lind - Bohanon', 'Folwell', 'Seward',
#        "Steven's Square - Loring Heights", 'Powderhorn Park',
#        'Phillips West', 'Lyndale', 'Elliot Park', 'Linden Hills',
#        'East Phillips', 'Audubon Park', 'Wenonah', 'Howe', 'Windom',
#        'Lowry Hill', 'Downtown West', 'Downtown East', 'Lynnhurst',
#        'North Loop', 'Cleveland', 'Shingle Creek', 'Armatage',
#        'Waite Park', 'Central', 'South Uptown', 'Hiawatha', 'Cooper',
#        'McKinley', 'Prospect Park - East River Road', 'St. Anthony West',
#        'Nicollet Island - East Bank', 'Harrison', 'Bryn - Mawr',
#        'Minnehaha', 'East Harriet', 'Northrop', 'St. Anthony East',
# ...

# %%
df['Neighborhood'].nunique()
# Out:
# 87

# %%
df[df['Precinct']==1]['Neighborhood'].unique()
# Out:
# array(['Loring Park', 'Elliot Park', 'Downtown West', 'Downtown East',
#        'North Loop', 'Cedar Riverside', 'University of Minnesota', nan],
#       dtype=object)

# %%
df.groupby('Precinct').all()
# Out:
#               X      Y  Type  Case_Number  Case_NumberAlt  Reported_Date  \
# Precinct
# 1.0       False  False  True         True            True           True
# 2.0       False  False  True         True            True           True
# 3.0       False  False  True         True            True           True
# 4.0       False  False  True         True            True           True
# 5.0       False  False  True         True            True           True
#
#           Occurred_Date  NIBRS_Crime_Against  NIBRS_Group  NIBRS_Code  \
# Precinct
# 1.0                True                 True         True        True
# 2.0                True                 True         True        True
# 3.0                True                 True         True        True
# 4.0                True                 True         True        True
# 5.0                True                 True         True        True
#
#           Offense_Category  Offense  Problem_Initial  Problem_Final  Address  \
# ...

# %%
df['Problem_Final'].nunique()
# Out:
# 150

# %%
df.head()
# Out:
#            X          Y                      Type Case_Number Case_NumberAlt  \
# 0 -93.305062  44.998752  Additional Crime Metrics   19-009342     MP20199342
# 1 -93.311416  44.995151  Additional Crime Metrics   19-013520    MP201913520
# 2 -93.290539  44.961813  Additional Crime Metrics   19-025082    MP201925082
# 3 -93.291154  45.007731  Additional Crime Metrics   19-030820    MP201930820
# 4 -93.258524  44.894316  Additional Crime Metrics   19-033021    MP201933021
#
#             Reported_Date           Occurred_Date NIBRS_Crime_Against  \
# 0  2019/01/10 13:00:00+00  2019/01/09 23:00:00+00      Non NIBRS Data
# 1  2019/01/14 17:42:00+00  2019/01/14 17:18:00+00      Non NIBRS Data
# 2  2019/01/26 14:15:00+00  2019/01/26 12:00:00+00      Non NIBRS Data
# 3  2019/02/01 16:39:00+00  2019/02/01 15:22:00+00      Non NIBRS Data
# 4  2019/02/03 23:12:00+00  2019/02/03 23:12:00+00      Non NIBRS Data
#
#       NIBRS_Group      NIBRS_Code                  Offense_Category  \
# ...

# %%
df[df['Offense_Category']=='Homicide Offenses ']
# Out:
#                 X          Y                    Type Case_Number  \
# 494    -93.276582  44.964583  Crime Offenses (NIBRS)   22-154977
# 690    -93.247331  44.957797  Crime Offenses (NIBRS)   22-155877
# 1022   -93.289521  45.000862  Crime Offenses (NIBRS)   22-161839
# 1621   -93.281020  45.002570  Crime Offenses (NIBRS)   22-173357
# 1684   -93.260044  44.940943  Crime Offenses (NIBRS)   22-041746
# ...           ...        ...                     ...         ...
# 248999 -93.312057  44.997887  Crime Offenses (NIBRS)   22-127179
# 249781 -93.272760  44.965747  Crime Offenses (NIBRS)   22-129575
# 250731 -93.277197  44.965219  Crime Offenses (NIBRS)   22-151696
# 251211 -93.288910  45.012213  Crime Offenses (NIBRS)   22-141422
# 251296 -93.274063  44.954629  Crime Offenses (NIBRS)   22-143710
#
#        Case_NumberAlt           Reported_Date           Occurred_Date  \
# 494      MP2022154977  2022/07/09 03:16:00+00  2022/07/09 03:12:00+00
# ...

# %%
df['Offense'].nunique()
# Out:
# 53

# %%
df['Time_To_Report']=pd.to_datetime(df['Reported_Date'])-pd.to_datetime(df['Occurred_Date'])

# %%
df_final=df[['Reported_Date','Occurred_Date','NIBRS_Group','NIBRS_Code','Offense_Category','Precinct','Ward','Neighborhood','Crime_Count','Time_To_Report']]

# %%
df_final.head()
# Out:
#             Reported_Date           Occurred_Date     NIBRS_Group  \
# 0  2019/01/10 13:00:00+00  2019/01/09 23:00:00+00  Non NIBRS Data
# 1  2019/01/14 17:42:00+00  2019/01/14 17:18:00+00  Non NIBRS Data
# 2  2019/01/26 14:15:00+00  2019/01/26 12:00:00+00  Non NIBRS Data
# 3  2019/02/01 16:39:00+00  2019/02/01 15:22:00+00  Non NIBRS Data
# 4  2019/02/03 23:12:00+00  2019/02/03 23:12:00+00  Non NIBRS Data
#
#        NIBRS_Code                  Offense_Category  Precinct  Ward  \
# 0  Non NIBRS Data  Subset of NIBRS Assault Offenses       4.0   5.0
# 1  Non NIBRS Data  Subset of NIBRS Assault Offenses       4.0   5.0
# 2  Non NIBRS Data  Subset of NIBRS Assault Offenses       5.0  10.0
# 3  Non NIBRS Data  Subset of NIBRS Assault Offenses       4.0   5.0
# 4  Non NIBRS Data  Subset of NIBRS Assault Offenses       3.0  11.0
#
#       Neighborhood  Crime_Count  Time_To_Report
# 0    Willard - Hay            1 0 days 14:00:00
# 1    Willard - Hay            1 0 days 00:24:00
# ...

# %%
df_final.isnull().sum()
# Out:
# Reported_Date          0
# Occurred_Date          1
# NIBRS_Group            0
# NIBRS_Code             0
# Offense_Category       0
# Precinct            1566
# Ward                1783
# Neighborhood        1647
# Crime_Count            0
# Time_To_Report         1
# dtype: int64

# %%
df_final=df_final.dropna(axis=0) # dropped rows with null values

# %%
df_final
# Out:
#                  Reported_Date           Occurred_Date     NIBRS_Group  \
# 0       2019/01/10 13:00:00+00  2019/01/09 23:00:00+00  Non NIBRS Data
# 1       2019/01/14 17:42:00+00  2019/01/14 17:18:00+00  Non NIBRS Data
# 2       2019/01/26 14:15:00+00  2019/01/26 12:00:00+00  Non NIBRS Data
# 3       2019/02/01 16:39:00+00  2019/02/01 15:22:00+00  Non NIBRS Data
# 4       2019/02/03 23:12:00+00  2019/02/03 23:12:00+00  Non NIBRS Data
# ...                        ...                     ...             ...
# 251522  2022/07/03 19:28:00+00  2022/07/02 00:00:00+00         Group A
# 251523  2022/07/17 17:54:00+00  2022/07/17 04:00:00+00         Group A
# 251524  2022/07/03 19:58:00+00  2022/07/03 00:00:00+00         Group A
# 251525  2022/07/11 13:15:00+00  2022/07/10 20:30:00+00         Group A
# 251526  2022/07/04 05:18:00+00  2022/07/03 21:30:00+00         Group A
#
#             NIBRS_Code                  Offense_Category  Precinct  Ward  \
# ...

# %%
df_final.isnull().sum()
# Out:
# Reported_Date       0
# Occurred_Date       0
# NIBRS_Group         0
# NIBRS_Code          0
# Offense_Category    0
# Precinct            0
# Ward                0
# Neighborhood        0
# Crime_Count         0
# Time_To_Report      0
# dtype: int64

# %%
# sorted(df['Reported_Date'],reverse=True)

# %%
df_final.head()
# Out:
#             Reported_Date           Occurred_Date     NIBRS_Group  \
# 0  2019/01/10 13:00:00+00  2019/01/09 23:00:00+00  Non NIBRS Data
# 1  2019/01/14 17:42:00+00  2019/01/14 17:18:00+00  Non NIBRS Data
# 2  2019/01/26 14:15:00+00  2019/01/26 12:00:00+00  Non NIBRS Data
# 3  2019/02/01 16:39:00+00  2019/02/01 15:22:00+00  Non NIBRS Data
# 4  2019/02/03 23:12:00+00  2019/02/03 23:12:00+00  Non NIBRS Data
#
#        NIBRS_Code                  Offense_Category  Precinct  Ward  \
# 0  Non NIBRS Data  Subset of NIBRS Assault Offenses       4.0   5.0
# 1  Non NIBRS Data  Subset of NIBRS Assault Offenses       4.0   5.0
# 2  Non NIBRS Data  Subset of NIBRS Assault Offenses       5.0  10.0
# 3  Non NIBRS Data  Subset of NIBRS Assault Offenses       4.0   5.0
# 4  Non NIBRS Data  Subset of NIBRS Assault Offenses       3.0  11.0
#
#       Neighborhood  Crime_Count  Time_To_Report
# 0    Willard - Hay            1 0 days 14:00:00
# 1    Willard - Hay            1 0 days 00:24:00
# ...

# %%
df['NIBRS_Group'].value_counts()
# Out:
# Group A           203936
# Non NIBRS Data     47591
# Name: NIBRS_Group, dtype: int64

# %%
df['NIBRS_Code'].value_counts()
# Out:
# Non NIBRS Data    47591
# 23H               27957
# 290               25634
# 240               24051
# 13B               18452
# 23F               18430
# 220               14629
# 13A               10911
# 23G                9261
# 120                8289
# 13C                7937
# 520                6265
# 35A                5986
# 26B                3951
# 26F                3370
# 23C                3285
# 280                2220
# 26A                1965
# 11D                1719
# 11A                1710
# 250                1433
# 35B                1109
# 23B                1084
# 100                 931
# 23D                 593
# 370                 552
# 200                 533
# 09A                 343
# 270                 245
# 26E                 245
# 11B                 223
# 210                 128
# 11C                 126
# 720                 114
# 64A                  49
# 26G                  38
# 23A                  33
# 64B                  31
# ...

# %%
df['Crime_Count'].value_counts()
# Out:
# 1     246440
# 2       3957
# 3        678
# 4        249
# 5        106
# 7         32
# 6         30
# 8         12
# 9          8
# 10         6
# 11         3
# 14         2
# 12         2
# 21         1
# 13         1
# Name: Crime_Count, dtype: int64

# %%
df['Offense_Category'].value_counts()
# Out:
# Larceny/Theft Offenses                       60652
# Shots Fired Calls                            39888
# Assault Offenses                             37300
# Destruction/Damage/Vandalism of Property     25634
# Motor Vehicle Theft                          24051
# Burglary/Breaking & Entering                 14629
# Fraud Offenses                                9596
# Robbery                                       8289
# Drug/Narcotic Offenses                        7095
# Weapon Law Violations                         6265
# Subset of NIBRS Assault Offenses              4180
# Sex Offenses                                  3790
# Stolen Property Offenses                      2220
# Gunshot Wound Victims                         1928
# Subset of NIBRS Robbery                       1595
# Counterfeiting/Forgery                        1433
# Kidnapping/Abduction                           931
# Pornography/Obscene Material                   552
# ...

# %%
df_final.to_pickle('df_final_db_project')

# %%
df_final.sort_values(by=['Occurred_Date'],ascending=True)
# Out:
#                  Reported_Date           Occurred_Date     NIBRS_Group  \
# 18011   2022/01/12 08:26:00+00  1922/01/09 10:30:00+00         Group A
# 5060    2022/08/20 12:30:00+00  1922/08/20 22:00:00+00         Group A
# 185774  2020/11/26 14:02:00+00  1961/09/01 01:00:00+00         Group A
# 178117  2020/09/09 18:49:00+00  1975/01/01 00:00:00+00         Group A
# 197332  2021/01/23 18:16:00+00  1982/01/01 17:00:00+00         Group A
# ...                        ...                     ...             ...
# 102270  2023/10/14 20:33:08+00  2023/10/14 20:33:08+00  Non NIBRS Data
# 98290   2023/10/14 21:50:04+00  2023/10/14 21:50:04+00  Non NIBRS Data
# 102131  2023/10/14 21:58:56+00  2023/10/14 21:58:56+00  Non NIBRS Data
# 100673  2023/10/14 22:01:58+00  2023/10/14 22:01:58+00  Non NIBRS Data
# 107321  2023/10/14 22:18:12+00  2023/10/14 22:18:12+00  Non NIBRS Data
#
#             NIBRS_Code                           Offense_Category  Precinct  \
# ...

# %%
df_temp=pd.read_csv('msp_temperature.csv')

# %%
df_temp.head()
# Out:
#          Date  Maximum Temperature degrees (F)  \
# 0  2010-01-01                              6.0
# 1  2010-01-02                              1.0
# 2  2010-01-03                              7.0
# 3  2010-01-04                              7.0
# 4  2010-01-05                             10.0
#
#    Minimum Temperature degrees (F) Precipitation (inches) Snow (inches)  \
# 0                             -9.0                      T             T
# 1                            -15.0                   0.00          0.00
# 2                            -14.0                   0.00          0.00
# 3                            -10.0                   0.00          0.00
# 4                             -9.0                   0.00          0.00
#
#   Snow Depth (inches)
# 0                9.00
# 1                9.00
# 2                9.00
# 3                9.00
# 4                9.00

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5035 entries, 0 to 5034
# Data columns (total 6 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Date                             5035 non-null   object
#  1   Maximum Temperature degrees (F)  5035 non-null   float64
#  2   Minimum Temperature degrees (F)  5035 non-null   float64
#  3   Precipitation (inches)           5035 non-null   object
#  4   Snow (inches)                    5035 non-null   object
#  5   Snow Depth (inches)              5035 non-null   object
# dtypes: float64(2), object(4)
# memory usage: 236.1+ KB

# %%
df_temp.isnull().sum()
# Out:
# Date                               0
# Maximum Temperature degrees (F)    0
# Minimum Temperature degrees (F)    0
# Precipitation (inches)             0
# Snow (inches)                      0
# Snow Depth (inches)                0
# dtype: int64

# %%
df_temp['Precipitation (inches)'].value_counts()
# Out:
# 0.00    2643
# T        750
# 0.01     233
# 0.02     123
# 0.03      90
#         ...
# 1.49       1
# 2.17       1
# 1.13       1
# 1.53       1
# 1.61       1
# Name: Precipitation (inches), Length: 166, dtype: int64

# %%
df_temp=df_temp.replace(to_replace='T',value=0.0)

# %%
df_temp
# Out:
#             Date  Maximum Temperature degrees (F)  \
# 0     2010-01-01                              6.0
# 1     2010-01-02                              1.0
# 2     2010-01-03                              7.0
# 3     2010-01-04                              7.0
# 4     2010-01-05                             10.0
# ...          ...                              ...
# 5030  2023-10-10                             58.0
# 5031  2023-10-11                             62.0
# 5032  2023-10-12                             55.0
# 5033  2023-10-13                             50.0
# 5034  2023-10-14                             56.0
#
#       Minimum Temperature degrees (F) Precipitation (inches) Snow (inches)  \
# 0                                -9.0                    0.0           0.0
# 1                               -15.0                   0.00          0.00
# 2                               -14.0                   0.00          0.00
# ...

# %%
df_temp['Date']=pd.to_datetime(df_temp['Date'])

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5035 entries, 0 to 5034
# Data columns (total 6 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Date                             5035 non-null   datetime64[ns]
#  1   Maximum Temperature degrees (F)  5035 non-null   float64
#  2   Minimum Temperature degrees (F)  5035 non-null   float64
#  3   Precipitation (inches)           5035 non-null   object
#  4   Snow (inches)                    5035 non-null   object
#  5   Snow Depth (inches)              5035 non-null   object
# dtypes: datetime64[ns](1), float64(2), object(3)
# memory usage: 236.1+ KB

# %%
df_temp.head()
# Out:
#         Date  Maximum Temperature degrees (F)  \
# 0 2010-01-01                              6.0
# 1 2010-01-02                              1.0
# 2 2010-01-03                              7.0
# 3 2010-01-04                              7.0
# 4 2010-01-05                             10.0
#
#    Minimum Temperature degrees (F) Precipitation (inches) Snow (inches)  \
# 0                             -9.0                    0.0           0.0
# 1                            -15.0                   0.00          0.00
# 2                            -14.0                   0.00          0.00
# 3                            -10.0                   0.00          0.00
# 4                             -9.0                   0.00          0.00
#
#   Snow Depth (inches)
# 0                9.00
# 1                9.00
# 2                9.00
# 3                9.00
# 4                9.00

# %%
df_test_time=pd.to_datetime(df_final['Occurred_Date'], format="%Y/%m/%d") # date formatting
df_final['Occurred Date Formatted']=df_test_time.dt.strftime("%Y-%m-%d")

# %%
df_final.rename(columns={'Occurred Date Formatted': 'Date'}, inplace=True)

# %%
df_final.head()
# Out:
#             Reported_Date           Occurred_Date     NIBRS_Group  \
# 0  2019/01/10 13:00:00+00  2019/01/09 23:00:00+00  Non NIBRS Data
# 1  2019/01/14 17:42:00+00  2019/01/14 17:18:00+00  Non NIBRS Data
# 2  2019/01/26 14:15:00+00  2019/01/26 12:00:00+00  Non NIBRS Data
# 3  2019/02/01 16:39:00+00  2019/02/01 15:22:00+00  Non NIBRS Data
# 4  2019/02/03 23:12:00+00  2019/02/03 23:12:00+00  Non NIBRS Data
#
#        NIBRS_Code                  Offense_Category  Precinct  Ward  \
# 0  Non NIBRS Data  Subset of NIBRS Assault Offenses       4.0   5.0
# 1  Non NIBRS Data  Subset of NIBRS Assault Offenses       4.0   5.0
# 2  Non NIBRS Data  Subset of NIBRS Assault Offenses       5.0  10.0
# 3  Non NIBRS Data  Subset of NIBRS Assault Offenses       4.0   5.0
# 4  Non NIBRS Data  Subset of NIBRS Assault Offenses       3.0  11.0
#
#       Neighborhood  Crime_Count  Time_To_Report        Date
# 0    Willard - Hay            1 0 days 14:00:00  2019-01-09
# ...

# %%
df_temp.head()
# Out:
#         Date  Maximum Temperature degrees (F)  \
# 0 2010-01-01                              6.0
# 1 2010-01-02                              1.0
# 2 2010-01-03                              7.0
# 3 2010-01-04                              7.0
# 4 2010-01-05                             10.0
#
#    Minimum Temperature degrees (F) Precipitation (inches) Snow (inches)  \
# 0                             -9.0                    0.0           0.0
# 1                            -15.0                   0.00          0.00
# 2                            -14.0                   0.00          0.00
# 3                            -10.0                   0.00          0.00
# 4                             -9.0                   0.00          0.00
#
#   Snow Depth (inches)
# 0                9.00
# 1                9.00
# 2                9.00
# 3                9.00
# 4                9.00

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5035 entries, 0 to 5034
# Data columns (total 6 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Date                             5035 non-null   datetime64[ns]
#  1   Maximum Temperature degrees (F)  5035 non-null   float64
#  2   Minimum Temperature degrees (F)  5035 non-null   float64
#  3   Precipitation (inches)           5035 non-null   object
#  4   Snow (inches)                    5035 non-null   object
#  5   Snow Depth (inches)              5035 non-null   object
# dtypes: datetime64[ns](1), float64(2), object(3)
# memory usage: 236.1+ KB

# %%
df_final['Date']=pd.to_datetime(df_final['Date'])

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 249652 entries, 0 to 251526
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Reported_Date     249652 non-null  object
#  1   Occurred_Date     249652 non-null  object
#  2   NIBRS_Group       249652 non-null  object
#  3   NIBRS_Code        249652 non-null  object
#  4   Offense_Category  249652 non-null  object
#  5   Precinct          249652 non-null  float64
#  6   Ward              249652 non-null  float64
#  7   Neighborhood      249652 non-null  object
#  8   Crime_Count       249652 non-null  int64
#  9   Time_To_Report    249652 non-null  timedelta64[ns]
#  10  Date              249652 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(6), timedelta64[ns](1)
# memory usage: 30.9+ MB

# %%
df_merge_testing=pd.merge(df_final, df_temp, on='Date', how='inner')

# %%
df_merge_testing.head()
# Out:
#             Reported_Date           Occurred_Date     NIBRS_Group  \
# 0  2019/01/10 13:00:00+00  2019/01/09 23:00:00+00  Non NIBRS Data
# 1  2019/01/09 10:56:00+00  2019/01/09 10:50:00+00  Non NIBRS Data
# 2  2019/01/09 09:32:00+00  2019/01/09 08:30:00+00  Non NIBRS Data
# 3  2019/01/09 14:47:00+00  2019/01/09 11:15:00+00         Group A
# 4  2019/01/10 08:41:00+00  2019/01/09 16:30:00+00         Group A
#
#        NIBRS_Code                  Offense_Category  Precinct  Ward  \
# 0  Non NIBRS Data  Subset of NIBRS Assault Offenses       4.0   5.0
# 1  Non NIBRS Data  Subset of NIBRS Assault Offenses       3.0   9.0
# 2  Non NIBRS Data  Subset of NIBRS Assault Offenses       4.0   4.0
# 3             250           Counterfeiting/Forgery        1.0   7.0
# 4            13B                  Assault Offenses        1.0   3.0
#
#        Neighborhood  Crime_Count  Time_To_Report       Date  \
# 0     Willard - Hay            1 0 days 14:00:00 2019-01-09
# ...

# %%
df_temp.to_pickle('temp_data')

# %%
df_merge_testing.sort_values(by='Occurred_Date').tail(30)
# Out:
#                  Reported_Date           Occurred_Date     NIBRS_Group  \
# 137230  2023/10/14 04:15:00+00  2023/10/14 01:36:00+00         Group A
# 137244  2023/10/14 01:36:39+00  2023/10/14 01:36:39+00  Non NIBRS Data
# 137232  2023/10/14 02:01:07+00  2023/10/14 02:01:07+00  Non NIBRS Data
# 137238  2023/10/14 02:13:50+00  2023/10/14 02:13:50+00  Non NIBRS Data
# 137243  2023/10/14 02:15:48+00  2023/10/14 02:15:48+00  Non NIBRS Data
# 137231  2023/10/14 03:09:00+00  2023/10/14 02:26:00+00         Group A
# 137227  2023/10/14 03:27:00+00  2023/10/14 02:45:00+00         Group A
# 137229  2023/10/14 02:49:00+00  2023/10/14 02:49:00+00         Group A
# 137252  2023/10/14 03:21:00+00  2023/10/14 03:21:00+00  Non NIBRS Data
# 137256  2023/10/14 03:44:16+00  2023/10/14 03:44:16+00  Non NIBRS Data
# 137250  2023/10/14 04:24:47+00  2023/10/14 04:24:47+00  Non NIBRS Data
# 137226  2023/10/14 04:51:00+00  2023/10/14 04:51:00+00         Group A
# ...

# %%
df_temp.sort_values(by='Date').tail()
# Out:
#            Date  Maximum Temperature degrees (F)  \
# 5030 2023-10-10                             58.0
# 5031 2023-10-11                             62.0
# 5032 2023-10-12                             55.0
# 5033 2023-10-13                             50.0
# 5034 2023-10-14                             56.0
#
#       Minimum Temperature degrees (F) Precipitation (inches) Snow (inches)  \
# 5030                             38.0                   0.00          0.00
# 5031                             38.0                   0.00          0.00
# 5032                             44.0                   0.33          0.00
# 5033                             46.0                   1.61          0.00
# 5034                             46.0                    0.0          0.00
#
#      Snow Depth (inches)
# 5030                0.00
# 5031                0.00
# 5032                0.00
# 5033                0.00
# 5034                0.00

# %%
df_merge_testing.to_pickle('df_merged')

# %%
df_merge_testing.head()
# Out:
#             Reported_Date           Occurred_Date     NIBRS_Group  \
# 0  2019/01/10 13:00:00+00  2019/01/09 23:00:00+00  Non NIBRS Data
# 1  2019/01/09 10:56:00+00  2019/01/09 10:50:00+00  Non NIBRS Data
# 2  2019/01/09 09:32:00+00  2019/01/09 08:30:00+00  Non NIBRS Data
# 3  2019/01/09 14:47:00+00  2019/01/09 11:15:00+00         Group A
# 4  2019/01/10 08:41:00+00  2019/01/09 16:30:00+00         Group A
#
#        NIBRS_Code                  Offense_Category  Precinct  Ward  \
# 0  Non NIBRS Data  Subset of NIBRS Assault Offenses       4.0   5.0
# 1  Non NIBRS Data  Subset of NIBRS Assault Offenses       3.0   9.0
# 2  Non NIBRS Data  Subset of NIBRS Assault Offenses       4.0   4.0
# 3             250           Counterfeiting/Forgery        1.0   7.0
# 4            13B                  Assault Offenses        1.0   3.0
#
#        Neighborhood  Crime_Count  Time_To_Report       Date  \
# 0     Willard - Hay            1 0 days 14:00:00 2019-01-09
# ...

# %%
df_merge_testing.drop(['NIBRS_Group','NIBRS_Group','Crime_Count'],axis=1,inplace=True)

# %%
df_merge_testing.head()
# Out:
#             Reported_Date           Occurred_Date      NIBRS_Code  \
# 0  2019/01/10 13:00:00+00  2019/01/09 23:00:00+00  Non NIBRS Data
# 1  2019/01/09 10:56:00+00  2019/01/09 10:50:00+00  Non NIBRS Data
# 2  2019/01/09 09:32:00+00  2019/01/09 08:30:00+00  Non NIBRS Data
# 3  2019/01/09 14:47:00+00  2019/01/09 11:15:00+00             250
# 4  2019/01/10 08:41:00+00  2019/01/09 16:30:00+00            13B
#
#                    Offense_Category  Precinct  Ward      Neighborhood  \
# 0  Subset of NIBRS Assault Offenses       4.0   5.0     Willard - Hay
# 1  Subset of NIBRS Assault Offenses       3.0   9.0  Midtown Phillips
# 2  Subset of NIBRS Assault Offenses       4.0   4.0          McKinley
# 3           Counterfeiting/Forgery        1.0   7.0       Elliot Park
# 4                 Assault Offenses        1.0   3.0     Downtown West
#
#    Time_To_Report       Date  Maximum Temperature degrees (F)  \
# 0 0 days 14:00:00 2019-01-09                             16.0
# ...

# %%
df_merge_testing.to_csv('merged_dataset')

# %%
df_merge_testing.sort_values(by='Reported_Date')
# Out:
#                  Reported_Date           Occurred_Date      NIBRS_Code  \
# 741     2019/01/01 00:01:58+00  2019/01/01 00:01:58+00  Non NIBRS Data
# 667     2019/01/01 00:02:07+00  2019/01/01 00:02:07+00  Non NIBRS Data
# 737     2019/01/01 00:02:59+00  2019/01/01 00:02:59+00  Non NIBRS Data
# 721     2019/01/01 00:03:44+00  2019/01/01 00:03:44+00  Non NIBRS Data
# 655     2019/01/01 00:04:01+00  2019/01/01 00:04:01+00  Non NIBRS Data
# ...                        ...                     ...             ...
# 137249  2023/10/14 20:33:08+00  2023/10/14 20:33:08+00  Non NIBRS Data
# 137234  2023/10/14 21:50:04+00  2023/10/14 21:50:04+00  Non NIBRS Data
# 137246  2023/10/14 21:58:56+00  2023/10/14 21:58:56+00  Non NIBRS Data
# 137237  2023/10/14 22:01:58+00  2023/10/14 22:01:58+00  Non NIBRS Data
# 137254  2023/10/14 22:18:12+00  2023/10/14 22:18:12+00  Non NIBRS Data
#
#          Offense_Category  Precinct  Ward    Neighborhood Time_To_Report  \
# ...

# %%
df_final
# Out:
#                  Reported_Date           Occurred_Date     NIBRS_Group  \
# 0       2019/01/10 13:00:00+00  2019/01/09 23:00:00+00  Non NIBRS Data
# 1       2019/01/14 17:42:00+00  2019/01/14 17:18:00+00  Non NIBRS Data
# 2       2019/01/26 14:15:00+00  2019/01/26 12:00:00+00  Non NIBRS Data
# 3       2019/02/01 16:39:00+00  2019/02/01 15:22:00+00  Non NIBRS Data
# 4       2019/02/03 23:12:00+00  2019/02/03 23:12:00+00  Non NIBRS Data
# ...                        ...                     ...             ...
# 251522  2022/07/03 19:28:00+00  2022/07/02 00:00:00+00         Group A
# 251523  2022/07/17 17:54:00+00  2022/07/17 04:00:00+00         Group A
# 251524  2022/07/03 19:58:00+00  2022/07/03 00:00:00+00         Group A
# 251525  2022/07/11 13:15:00+00  2022/07/10 20:30:00+00         Group A
# 251526  2022/07/04 05:18:00+00  2022/07/03 21:30:00+00         Group A
#
#             NIBRS_Code                  Offense_Category  Precinct  Ward  \
# ...

# %%
df_final.sort_values(by='Date')
# Out:
#                  Reported_Date           Occurred_Date     NIBRS_Group  \
# 18011   2022/01/12 08:26:00+00  1922/01/09 10:30:00+00         Group A
# 5060    2022/08/20 12:30:00+00  1922/08/20 22:00:00+00         Group A
# 185774  2020/11/26 14:02:00+00  1961/09/01 01:00:00+00         Group A
# 178117  2020/09/09 18:49:00+00  1975/01/01 00:00:00+00         Group A
# 197332  2021/01/23 18:16:00+00  1982/01/01 17:00:00+00         Group A
# ...                        ...                     ...             ...
# 100652  2023/10/14 05:04:05+00  2023/10/14 05:04:05+00  Non NIBRS Data
# 108083  2023/10/14 00:05:44+00  2023/10/14 00:05:44+00  Non NIBRS Data
# 108084  2023/10/14 03:44:16+00  2023/10/14 03:44:16+00  Non NIBRS Data
# 99554   2023/10/14 19:12:28+00  2023/10/14 19:12:28+00  Non NIBRS Data
# 107319  2023/10/14 03:21:00+00  2023/10/14 03:21:00+00  Non NIBRS Data
#
#             NIBRS_Code                           Offense_Category  Precinct  \
# ...

# %%
df_test1=df_final[df_final['Date'] > pd.to_datetime('2019-01-01')]

# %%
df_test1=df_final[df_final['Date'] < pd.to_datetime('2023-01-01')]

# %%
df_test1.sort_values(by='Date',ascending=False)
# Out:
#                  Reported_Date           Occurred_Date NIBRS_Group NIBRS_Code  \
# 29216   2023/01/02 13:29:00+00  2022/12/31 12:00:00+00     Group A        220
# 41686   2023/01/01 10:09:00+00  2022/12/31 17:00:00+00     Group A        240
# 16067   2022/12/31 17:38:00+00  2022/12/31 17:38:00+00     Group A       35A
# 16069   2022/12/31 17:55:00+00  2022/12/31 17:55:00+00     Group A       13B
# 16071   2022/12/31 23:59:00+00  2022/12/31 16:30:00+00     Group A        240
# ...                        ...                     ...         ...        ...
# 197332  2021/01/23 18:16:00+00  1982/01/01 17:00:00+00     Group A       11A
# 178117  2020/09/09 18:49:00+00  1975/01/01 00:00:00+00     Group A       11A
# 185774  2020/11/26 14:02:00+00  1961/09/01 01:00:00+00     Group A       11A
# 5060    2022/08/20 12:30:00+00  1922/08/20 22:00:00+00     Group A        290
# 18011   2022/01/12 08:26:00+00  1922/01/09 10:30:00+00     Group A       23G
#
# ...

# %%
df_final=df_test1

# %%
df=df[(df['Date'] > pd.to_datetime('2019-01-01')) &(df['Date'] < pd.to_datetime('2023-01-01'))]

# %%
df_temp.sort_values(by='Date',ascending=True)
# Out:
#            Date  Maximum Temperature degrees (F)  \
# 3288 2019-01-02                             26.0
# 3289 2019-01-03                             41.0
# 3290 2019-01-04                             47.0
# 3291 2019-01-05                             47.0
# 3292 2019-01-06                             38.0
# ...         ...                              ...
# 4743 2022-12-27                             26.0
# 4744 2022-12-28                             38.0
# 4745 2022-12-29                             37.0
# 4746 2022-12-30                             25.0
# 4747 2022-12-31                             36.0
#
#       Minimum Temperature degrees (F) Precipitation (inches) Snow (inches)  \
# 3288                              2.0                    0.0           0.0
# 3289                             20.0                   0.00          0.00
# 3290                             28.0                   0.00          0.00
# ...

# %%
df_merge_testing=pd.merge(df_final, df_temp, on='Date', how='inner')

# %%
df_merge_testing.sort_values('Date')
# Out:
#                 Reported_Date           Occurred_Date NIBRS_Group NIBRS_Code  \
# 5597   2019/01/03 00:41:00+00  2019/01/02 23:32:00+00     Group A       13C
# 5639   2019/01/02 10:09:00+00  2019/01/02 08:00:00+00     Group A       13B
# 5638   2019/01/02 05:57:00+00  2019/01/02 05:07:00+00     Group A       13B
# 5637   2019/04/25 12:44:00+00  2019/01/02 00:01:00+00     Group A       23G
# 5636   2019/02/15 12:33:00+00  2019/01/02 12:00:00+00     Group A        250
# ...                       ...                     ...         ...        ...
# 67977  2022/12/31 21:21:00+00  2022/12/31 21:21:00+00     Group A        290
# 67978  2022/12/31 17:38:00+00  2022/12/31 04:36:00+00     Group A       23G
# 67979  2023/01/01 17:45:00+00  2022/12/31 21:00:00+00     Group A       23F
# 68000  2023/01/01 10:09:00+00  2022/12/31 17:00:00+00     Group A        240
# 67958  2022/12/31 02:39:00+00  2022/12/31 02:39:00+00     Group A        520
#
# ...

# %%
df_merge_testing.drop(['NIBRS_Group','NIBRS_Group','Crime_Count'],axis=1,inplace=True)

# %%
df_merge_testing.drop('NIBRS_Code',axis=1,inplace=True)

# %%
df_merge_testing.drop(['Reported_Date','Occurred_Date'],axis=1,inplace=True)

# %%
df_merge_testing
# Out:
#                         Offense_Category  Precinct  Ward      Neighborhood  \
# 0       Subset of NIBRS Assault Offenses       4.0   5.0     Willard - Hay
# 1       Subset of NIBRS Assault Offenses       3.0   9.0  Midtown Phillips
# 2       Subset of NIBRS Assault Offenses       4.0   4.0          McKinley
# 3                Counterfeiting/Forgery        1.0   7.0       Elliot Park
# 4                      Assault Offenses        1.0   3.0     Downtown West
# ...                                  ...       ...   ...               ...
# 207030           Larceny/Theft Offenses        3.0  11.0         Keewaydin
# 207031           Larceny/Theft Offenses        3.0  12.0          Standish
# 207032           Larceny/Theft Offenses        3.0  12.0          Standish
# 207033                   Fraud Offenses        5.0  10.0          Whittier
# 207034           Larceny/Theft Offenses        3.0   6.0            Seward
#
# ...

# %%
df_merge_testing.columns
# Out:
# Index(['Offense_Category', 'Precinct', 'Ward', 'Neighborhood',
#        'Time_To_Report', 'Date', 'Maximum Temperature degrees (F)',
#        'Minimum Temperature degrees (F)', 'Precipitation (inches)',
#        'Snow (inches)', 'Snow Depth (inches)'],
#       dtype='object')

# %%
df_merge_testing.to_pickle('final_project_dataset')

# %%
df_merge_testing.to_csv('final_project_dataset_csv')

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('data.csv')

# %%
df['Date']=pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.strftime('%B')
df['Time_To_Report_days']=df['Time_To_Report'].str.split().str[0]
df['Mean_Temperature_F']=(df['Maximum Temperature degrees (F)']+df['Minimum Temperature degrees (F)'])/2
df['Year']=df['Date'].dt.year

# %%
df.head()
# Out:
#                    Offense_Category  Precinct  Ward      Neighborhood  \
# 0  Subset of NIBRS Assault Offenses       4.0   5.0     Willard - Hay
# 1  Subset of NIBRS Assault Offenses       3.0   9.0  Midtown Phillips
# 2  Subset of NIBRS Assault Offenses       4.0   4.0          McKinley
# 3           Counterfeiting/Forgery        1.0   7.0       Elliot Park
# 4                 Assault Offenses        1.0   3.0     Downtown West
#
#     Time_To_Report       Date  Maximum Temperature degrees (F)  \
# 0  0 days 14:00:00 2019-01-09                             16.0
# 1  0 days 00:06:00 2019-01-09                             16.0
# 2  0 days 01:02:00 2019-01-09                             16.0
# 3  0 days 03:32:00 2019-01-09                             16.0
# 4  0 days 16:11:00 2019-01-09                             16.0
#
#    Minimum Temperature degrees (F)  Precipitation (inches)  Snow (inches)  \
# 0                              6.0                     0.0            0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207035 entries, 0 to 207034
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Offense_Category                 207035 non-null  object
#  1   Precinct                         207035 non-null  float64
#  2   Ward                             207035 non-null  float64
#  3   Neighborhood                     207035 non-null  object
#  4   Time_To_Report                   207035 non-null  object
#  5   Date                             207035 non-null  datetime64[ns]
#  6   Maximum Temperature degrees (F)  207035 non-null  float64
#  7   Minimum Temperature degrees (F)  207035 non-null  float64
#  8   Precipitation (inches)           207035 non-null  float64
#  9   Snow (inches)                    207035 non-null  float64
#  10  Snow Depth (inches)              207035 non-null  float64
# ...

# %%
df.to_csv('final_data_dec_2',index=False)

# %%
del(df['Time_To_Report'])

# %%
df.head()
# Out:
#                    Offense_Category  Precinct  Ward      Neighborhood  \
# 0  Subset of NIBRS Assault Offenses       4.0   5.0     Willard - Hay
# 1  Subset of NIBRS Assault Offenses       3.0   9.0  Midtown Phillips
# 2  Subset of NIBRS Assault Offenses       4.0   4.0          McKinley
# 3           Counterfeiting/Forgery        1.0   7.0       Elliot Park
# 4                 Assault Offenses        1.0   3.0     Downtown West
#
#         Date  Maximum Temperature degrees (F)  \
# 0 2019-01-09                             16.0
# 1 2019-01-09                             16.0
# 2 2019-01-09                             16.0
# 3 2019-01-09                             16.0
# 4 2019-01-09                             16.0
#
#    Minimum Temperature degrees (F)  Precipitation (inches)  Snow (inches)  \
# 0                              6.0                     0.0            0.0
# 1                              6.0                     0.0            0.0
# ...

# %%
import seaborn as sns
# Out:
# /Users/prakritsinha/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
sns.barplot(x=df.groupby('Precinct').count().sort_values(by='Ward',ascending=False)['Ward'].index,y=df.groupby('Precinct').count().sort_values(by='Ward',ascending=False)['Ward'].values)
# Out:
# <Axes: xlabel='Precinct'>

# %%
df.groupby('Precinct').count().sort_values(by='Ward',ascending=False)
# Out:
#           Offense_Category   Ward  Neighborhood   Date  \
# Precinct
# 4.0                  58647  58647         58647  58647
# 3.0                  54277  54277         54277  54277
# 5.0                  37104  37104         37104  37104
# 1.0                  31042  31042         31042  31042
# 2.0                  25965  25965         25965  25965
#
#           Maximum Temperature degrees (F)  Minimum Temperature degrees (F)  \
# Precinct
# 4.0                                 58647                            58647
# 3.0                                 54277                            54277
# 5.0                                 37104                            37104
# 1.0                                 31042                            31042
# 2.0                                 25965                            25965
#
#           Precipitation (inches)  Snow (inches)  Snow Depth (inches)  Month  \
# Precinct
# ...

# %%
df.head()
# Out:
#                    Offense_Category  Precinct  Ward      Neighborhood  \
# 0  Subset of NIBRS Assault Offenses       4.0   5.0     Willard - Hay
# 1  Subset of NIBRS Assault Offenses       3.0   9.0  Midtown Phillips
# 2  Subset of NIBRS Assault Offenses       4.0   4.0          McKinley
# 3           Counterfeiting/Forgery        1.0   7.0       Elliot Park
# 4                 Assault Offenses        1.0   3.0     Downtown West
#
#         Date  Maximum Temperature degrees (F)  \
# 0 2019-01-09                             16.0
# 1 2019-01-09                             16.0
# 2 2019-01-09                             16.0
# 3 2019-01-09                             16.0
# 4 2019-01-09                             16.0
#
#    Minimum Temperature degrees (F)  Precipitation (inches)  Snow (inches)  \
# 0                              6.0                     0.0            0.0
# 1                              6.0                     0.0            0.0
# ...

# %%
df.to_csv('final_Data_dec_3',date_format='%Y-%m-%d',index=False)

# %%
df_new=pd.read_csv('final_Data_dec_3')
df_new.head()
# Out:
#                    Offense_Category  Precinct  Ward      Neighborhood  \
# 0  Subset of NIBRS Assault Offenses       4.0   5.0     Willard - Hay
# 1  Subset of NIBRS Assault Offenses       3.0   9.0  Midtown Phillips
# 2  Subset of NIBRS Assault Offenses       4.0   4.0          McKinley
# 3           Counterfeiting/Forgery        1.0   7.0       Elliot Park
# 4                 Assault Offenses        1.0   3.0     Downtown West
#
#          Date  Maximum Temperature degrees (F)  \
# 0  2019-01-09                             16.0
# 1  2019-01-09                             16.0
# 2  2019-01-09                             16.0
# 3  2019-01-09                             16.0
# 4  2019-01-09                             16.0
#
#    Minimum Temperature degrees (F)  Precipitation (inches)  Snow (inches)  \
# 0                              6.0                     0.0            0.0
# 1                              6.0                     0.0            0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207035 entries, 0 to 207034
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Offense_Category                 207035 non-null  object
#  1   Precinct                         207035 non-null  float64
#  2   Ward                             207035 non-null  float64
#  3   Neighborhood                     207035 non-null  object
#  4   Date                             207035 non-null  datetime64[ns]
#  5   Maximum Temperature degrees (F)  207035 non-null  float64
#  6   Minimum Temperature degrees (F)  207035 non-null  float64
#  7   Precipitation (inches)           207035 non-null  float64
#  8   Snow (inches)                    207035 non-null  float64
#  9   Snow Depth (inches)              207035 non-null  float64
#  10  Month                            207035 non-null  object
# ...

# %%
df['Time_To_Report_days'] = df['Time_To_Report_days'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207035 entries, 0 to 207034
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Offense_Category                 207035 non-null  object
#  1   Precinct                         207035 non-null  float64
#  2   Ward                             207035 non-null  float64
#  3   Neighborhood                     207035 non-null  object
#  4   Date                             207035 non-null  datetime64[ns]
#  5   Maximum Temperature degrees (F)  207035 non-null  float64
#  6   Minimum Temperature degrees (F)  207035 non-null  float64
#  7   Precipitation (inches)           207035 non-null  float64
#  8   Snow (inches)                    207035 non-null  float64
#  9   Snow Depth (inches)              207035 non-null  float64
#  10  Month                            207035 non-null  object
# ...

# %%
df.head()
# Out:
#                    Offense_Category  Precinct  Ward      Neighborhood  \
# 0  Subset of NIBRS Assault Offenses       4.0   5.0     Willard - Hay
# 1  Subset of NIBRS Assault Offenses       3.0   9.0  Midtown Phillips
# 2  Subset of NIBRS Assault Offenses       4.0   4.0          McKinley
# 3           Counterfeiting/Forgery        1.0   7.0       Elliot Park
# 4                 Assault Offenses        1.0   3.0     Downtown West
#
#         Date  Maximum Temperature degrees (F)  \
# 0 2019-01-09                             16.0
# 1 2019-01-09                             16.0
# 2 2019-01-09                             16.0
# 3 2019-01-09                             16.0
# 4 2019-01-09                             16.0
#
#    Minimum Temperature degrees (F)  Precipitation (inches)  Snow (inches)  \
# 0                              6.0                     0.0            0.0
# 1                              6.0                     0.0            0.0
# ...

# %%
df['Time_To_Report_days'].value_counts()
# Out:
# 0      163544
# 1       12486
# 2        6645
# 3        4137
# 4        2857
#         ...
# 434         1
# 603         1
# 441         1
# 822         1
# 778         1
# Name: Time_To_Report_days, Length: 649, dtype: int64

# %%
df['Precinct'] = df['Precinct'].astype('int64')
df['Ward'] = df['Ward'].astype('int64')

# %%
df.head()
# Out:
#                    Offense_Category  Precinct  Ward      Neighborhood  \
# 0  Subset of NIBRS Assault Offenses         4     5     Willard - Hay
# 1  Subset of NIBRS Assault Offenses         3     9  Midtown Phillips
# 2  Subset of NIBRS Assault Offenses         4     4          McKinley
# 3           Counterfeiting/Forgery          1     7       Elliot Park
# 4                 Assault Offenses          1     3     Downtown West
#
#         Date  Maximum Temperature degrees (F)  \
# 0 2019-01-09                             16.0
# 1 2019-01-09                             16.0
# 2 2019-01-09                             16.0
# 3 2019-01-09                             16.0
# 4 2019-01-09                             16.0
#
#    Minimum Temperature degrees (F)  Precipitation (inches)  Snow (inches)  \
# 0                              6.0                     0.0            0.0
# 1                              6.0                     0.0            0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207035 entries, 0 to 207034
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Offense_Category                 207035 non-null  object
#  1   Precinct                         207035 non-null  int64
#  2   Ward                             207035 non-null  int64
#  3   Neighborhood                     207035 non-null  object
#  4   Date                             207035 non-null  datetime64[ns]
#  5   Maximum Temperature degrees (F)  207035 non-null  float64
#  6   Minimum Temperature degrees (F)  207035 non-null  float64
#  7   Precipitation (inches)           207035 non-null  float64
#  8   Snow (inches)                    207035 non-null  float64
#  9   Snow Depth (inches)              207035 non-null  float64
#  10  Month                            207035 non-null  object
# ...

# %%
df.to_csv('final_Data_dec_3',date_format='%Y-%m-%d',index=False)

# %%
data=pd.read_csv('final_Data_dec_3')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207035 entries, 0 to 207034
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Offense_Category                 207035 non-null  object
#  1   Precinct                         207035 non-null  int64
#  2   Ward                             207035 non-null  int64
#  3   Neighborhood                     207035 non-null  object
#  4   Date                             207035 non-null  object
#  5   Maximum Temperature degrees (F)  207035 non-null  float64
#  6   Minimum Temperature degrees (F)  207035 non-null  float64
#  7   Precipitation (inches)           207035 non-null  float64
#  8   Snow (inches)                    207035 non-null  float64
#  9   Snow Depth (inches)              207035 non-null  float64
#  10  Month                            207035 non-null  object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207035 entries, 0 to 207034
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Offense_Category                 207035 non-null  object
#  1   Precinct                         207035 non-null  int64
#  2   Ward                             207035 non-null  int64
#  3   Neighborhood                     207035 non-null  object
#  4   Date                             207035 non-null  datetime64[ns]
#  5   Maximum Temperature degrees (F)  207035 non-null  float64
#  6   Minimum Temperature degrees (F)  207035 non-null  float64
#  7   Precipitation (inches)           207035 non-null  float64
#  8   Snow (inches)                    207035 non-null  float64
#  9   Snow Depth (inches)              207035 non-null  float64
#  10  Month                            207035 non-null  object
# ...

# %% [markdown]
# ### Answering key questions

# %% [markdown]
# ##### Q1. 1. List the total number of reported crimes between 2019 and 2022?

# %%
df['Neighborhood'].nunique()
# Out:
# 87

# %%
len(df)
# Out:
# 207035

# %% [markdown]
# ##### 207,035 crimes were reported in the 87 neighbourhoods of Minneapolis from 2019-2022.

# %% [markdown]
# ##### Which are the 3 most common crimes reported and what percentage amount are they from the total amount of reported crimes?

# %%
df.groupby('Offense_Category').count().sort_values(by='Precinct',ascending=False)
# Out:
#                                            Precinct   Ward  Neighborhood  \
# Offense_Category
# Larceny/Theft Offenses                        50898  50898         50898
# Shots Fired Calls                             34419  34419         34419
# Assault Offenses                              30598  30598         30598
# Destruction/Damage/Vandalism of Property      20452  20452         20452
# Motor Vehicle Theft                           17567  17567         17567
# Burglary/Breaking & Entering                  12467  12467         12467
# Fraud Offenses                                 7995   7995          7995
# Robbery                                        7123   7123          7123
# Drug/Narcotic Offenses                         5764   5764          5764
# Weapon Law Violations                          5026   5026          5026
# Subset of NIBRS Assault Offenses               3435   3435          3435
# Sex Offenses                                   2768   2768          2768
# ...

# %%
Series1=df.groupby('Mean_Temperature_F').count().sort_values('Mean_Temperature_F')['Ward']

# %%
sns.lineplot(x=Series1.index,y=Series1.values)
# Out:
# <Axes: xlabel='Mean_Temperature_F'>

# %%
Series1=df[df['Year']==2021].groupby('Mean_Temperature_F').count()['Ward']

# %%
Series1.to_csv('hypothesis_test_data')

# %%
Series1
# Out:
# Mean_Temperature_F
# -11.5    108
# -9.5      96
# -8.5     179
# -7.5     106
# -4.5     314
#         ...
#  85.0    332
#  85.5    297
#  86.0    109
#  86.5    143
#  88.5    177
# Name: Ward, Length: 147, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207035 entries, 0 to 207034
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Offense_Category                 207035 non-null  object
#  1   Precinct                         207035 non-null  int64
#  2   Ward                             207035 non-null  int64
#  3   Neighborhood                     207035 non-null  object
#  4   Date                             207035 non-null  datetime64[ns]
#  5   Maximum Temperature degrees (F)  207035 non-null  float64
#  6   Minimum Temperature degrees (F)  207035 non-null  float64
#  7   Precipitation (inches)           207035 non-null  float64
#  8   Snow (inches)                    207035 non-null  float64
#  9   Snow Depth (inches)              207035 non-null  float64
#  10  Month                            207035 non-null  object
# ...

# %%
df['Offense_Category'].unique()
# Out:
# array(['Subset of NIBRS Assault Offenses', 'Counterfeiting/Forgery ',
#        'Assault Offenses ', 'Shots Fired Calls',
#        'Larceny/Theft Offenses ', 'Robbery ', 'Drug/Narcotic Offenses ',
#        'Burglary/Breaking & Entering ', 'Motor Vehicle Theft ',
#        'Fraud Offenses ', 'Weapon Law Violations ',
#        'Kidnapping/Abduction ',
#        'Destruction/Damage/Vandalism of Property ',
#        'Stolen Property Offenses ', 'Embezzlement ',
#        'Pornography/Obscene Material ', 'Sex Offenses ',
#        'Gunshot Wound Victims', 'Bribery ', 'Arson ',
#        'Extortion/Blackmail ', 'Homicide Offenses ', 'Animal Cruelty ',
#        'Human Trafficking ', 'Prostitution Offenses ',
#        'Subset of NIBRS Robbery', 'Gambling Offenses '], dtype=object)

# %% [markdown]
# What month had the most homicides reported and what was the average temperature in the last four years?

# %%
df[df['Offense_Category']=='Homicide Offenses ']
# Out:
#           Offense_Category  Precinct  Ward     Neighborhood       Date  \
# 684     Homicide Offenses          5     8          Lyndale 2019-01-03
# 1815    Homicide Offenses          2     3     Marcy Holmes 2019-02-09
# 2938    Homicide Offenses          4     4         McKinley 2019-05-01
# 4843    Homicide Offenses          4     4        Cleveland 2019-01-19
# 5226    Homicide Offenses          5    10         Whittier 2019-05-30
# ...                    ...       ...   ...              ...        ...
# 199101  Homicide Offenses          3     6  Ventura Village 2021-03-17
# 199589  Homicide Offenses          3     9    East Phillips 2021-03-24
# 200665  Homicide Offenses          3     9  Powderhorn Park 2021-04-23
# 202353  Homicide Offenses          4     4          Folwell 2021-06-10
# 204479  Homicide Offenses          4     4   Lind - Bohanon 2021-06-15
#
#         Maximum Temperature degrees (F)  Minimum Temperature degrees (F)  \
# ...

# %%
df[df['Offense_Category']=='Homicide Offenses '].groupby('Month').count()['Offense_Category']
# Out:
# Month
# April        24
# August       42
# December     24
# February     20
# January      12
# July         38
# June         35
# March        18
# May          30
# November     23
# October      24
# September    29
# Name: Offense_Category, dtype: int64

# %%
df.columns
# Out:
# Index(['Offense_Category', 'Precinct', 'Ward', 'Neighborhood', 'Date',
#        'Maximum Temperature degrees (F)', 'Minimum Temperature degrees (F)',
#        'Precipitation (inches)', 'Snow (inches)', 'Snow Depth (inches)',
#        'Month', 'Time_To_Report_days', 'Mean_Temperature_F', 'Year'],
#       dtype='object')

# %%
df.groupby('Month').mean()
# Out:
#            Precinct      Ward  Maximum Temperature degrees (F)  \
# Month
# April      3.212499  6.188814                        54.659192
# August     3.186778  6.266847                        81.583681
# December   3.218805  6.305885                        30.988839
# February   3.175864  6.251188                        24.266817
# January    3.200804  6.261741                        24.655784
# July       3.198867  6.263104                        85.140491
# June       3.240633  6.274700                        83.159511
# March      3.213387  6.268704                        43.633522
# May        3.239864  6.221106                        69.290823
# November   3.243685  6.284984                        44.080837
# October    3.226774  6.194452                        58.529055
# September  3.225866  6.246464                        74.677444
#
#            Minimum Temperature degrees (F)  Precipitation (inches)  \
# Month
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = (18, 7)
color = plt.cm.copper(np.linspace(0, 1, 50))
temp_df['col'].value_counts().head(40).plot.bar(color = color)
plt.title('frequency of most popular items', fontsize = 20)
plt.xticks(rotation = 90)
plt.grid()
plt.show()

# %%
df['Offense_Category'].nunique()
# Out:
# 27

# %% [markdown]
# ### plot for question 2

# %%
order = df['Offense_Category'].value_counts().index
plt.figure(figsize=(12, 8))
sns.countplot(x='Offense_Category', data=df, order=order)
plt.xticks(rotation=90)
plt.title('Type Of Crime')
plt.show()

# %% [markdown]
# ### plot for Q3

# %%
order = df['Neighborhood'].value_counts().index
plt.figure(figsize=(20, 10))
sns.countplot(x='Neighborhood', data=df, order=order)
plt.title('Crime Based On Neighborhood')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### plot for Q4

# %%
order = df['Month'].value_counts().index
plt.figure(figsize=(20, 10))
sns.countplot(x='Month', data=df, order=order)
plt.xticks(rotation=90)
plt.ylabel('Crime Count')
plt.title('Crime Based On Month')
plt.show()

# %% [markdown]
# ### plot for Q5

# %%
percent_change=(df[df['Year']==2019].groupby('Offense_Category').count()['Ward'].values-df[df['Year']==2022].groupby('Offense_Category').count()['Ward'].values)/df[df['Year']==2019].groupby('Offense_Category').count()['Ward'].values
crime_type=df[df['Year']==2019].groupby('Offense_Category').count()['Ward'].index

# %%
plt.figure(figsize=(20, 10))
sns.barplot(x=crime_type, y=percent_change)
plt.xticks(rotation=90)
# plt.ylabel('Crime Count')
plt.show()

# %% [markdown]
# ### plot for Q6

# %%
crime_per_date=df.groupby(by='Date').count()['Ward']
snow_per_date=df.groupby(by='Date').mean()['Snow Depth (inches)']

plt.figure(figsize=(20, 10))

ax = sns.lineplot(x=crime_per_date.index, y=crime_per_date.values, label='Crime')

ax2 = ax.twinx()

sns.lineplot(x=snow_per_date.index, y=snow_per_date.values, ax=ax2, color='orange', label='Snow (inches)')

ax.set_ylabel('Crime')
ax2.set_ylabel('snow')
plt.xlabel('Date')


ax.legend(loc='upper left')

# %% [markdown]
# ### plot for question 7

# %%
obj=df.groupby('Year').count()['Ward']

plt.figure(figsize=(12, 6))

plt.title('Number Of Crimes Per Year')
sns.barplot(x=obj.index, y=obj.values)
# Out:
# <Axes: title={'center': 'Number Of Crimes Per Year'}, xlabel='Year'>

# %% [markdown]
# ### plot for Q8

# %%
crime_per_date=df.groupby(by='Date').count()['Ward']
temp_per_date=df.groupby(by='Date').mean()['Mean_Temperature_F']

plt.figure(figsize=(20, 10))

ax = sns.lineplot(x=crime_per_date.index, y=crime_per_date.values, label='Crime')

ax2 = ax.twinx()

sns.lineplot(x=temp_per_date.index, y=temp_per_date.values, ax=ax2, color='orange', label='Temperature')

ax.set_ylabel('Crime')
ax2.set_ylabel('Temperature')
plt.xlabel('Date')


ax.legend(loc='upper left')

# %% [markdown]
# ### plot for Q10

# %%
round(df[df['Year']==2021].groupby('Month').mean(),2)
# Out:
#            Precinct  Ward  Maximum Temperature degrees (F)  \
# Month
# April          3.34  6.15                            57.35
# August         3.21  6.09                            82.91
# December       3.22  6.31                            32.79
# February       3.19  6.28                            19.54
# January        3.21  6.44                            28.04
# July           3.23  6.16                            86.30
# June           3.28  6.23                            87.26
# March          3.26  6.20                            50.19
# May            3.27  6.05                            70.80
# November       3.27  6.17                            45.64
# October        3.25  6.17                            64.51
# September      3.25  6.15                            76.91
#
#            Minimum Temperature degrees (F)  Precipitation (inches)  \
# Month
# April                                38.21                    0.08
# ...

# %%
df[df['Year']==2021].groupby('Month').count()
# Out:
#            Offense_Category  Precinct  Ward  Neighborhood  Date  \
# Month
# April                  3836      3836  3836          3836  3836
# August                 4885      4885  4885          4885  4885
# December               4279      4279  4279          4279  4279
# February               2973      2973  2973          2973  2973
# January                3851      3851  3851          3851  3851
# July                   4848      4848  4848          4848  4848
# June                   4622      4622  4622          4622  4622
# March                  3509      3509  3509          3509  3509
# May                    4889      4889  4889          4889  4889
# November               4752      4752  4752          4752  4752
# October                5015      5015  5015          5015  5015
# September              5076      5076  5076          5076  5076
#
#            Maximum Temperature degrees (F)  Minimum Temperature degrees (F)  \
# Month
# ...

# %%
month_lst=['Jan','Feb','Mar','Apr','May','June','July','Aug','Sep','Oct','Nov','Dec']
crime_vals=[3851,2973,3509,3836,4889,4622,4848,4885,5076,5015,4752,4279]
avg_temp=[22.03,12.58,40.58,47.78,61.03,76.59,76.15,73.93,66.61,56.16,37.76,24.73]
plt.figure(figsize=(30, 10))

ax = sns.lineplot(x=month_lst, y=crime_vals, label='Crime')

ax2 = ax.twinx()

sns.lineplot(x=month_lst, y=avg_temp, ax=ax2, color='orange', label='Mean Temperature')

ax.tick_params(axis='both', which='both', labelsize=16)
ax2.tick_params(axis='both', which='both', labelsize=16)


ax.set_ylabel('Crime',fontsize=20)
ax2.set_ylabel('Temperature',fontsize=20)
plt.title('2021 Month Vs Crime',fontsize=20)

ax.legend(loc='upper left',fontsize=20)
ax2.legend(fontsize=20)

# %%
df.describe()
# Out:
#             Precinct           Ward  Maximum Temperature degrees (F)  \
# count  207035.000000  207035.000000                    207035.000000
# mean        3.216418       6.251885                        59.219905
# std         1.295556       3.076300                        23.668724
# min         1.000000       1.000000                       -13.000000
# 25%         2.000000       4.000000                        39.000000
# 50%         3.000000       6.000000                        64.000000
# 75%         4.000000       9.000000                        80.000000
# max         5.000000      13.000000                       101.000000
#
#        Minimum Temperature degrees (F)  Precipitation (inches)  Snow (inches)  \
# count                    207035.000000           207035.000000  207035.000000
# mean                         41.723684                0.082046       0.128180
# std                          21.990249                0.237221       0.729737
# ...

# %%
np.median(df['Time_To_Report_days'])
# Out:
# 0.0

# %%
df.head()
# Out:
#                    Offense_Category  Precinct  Ward      Neighborhood  \
# 0  Subset of NIBRS Assault Offenses         4     5     Willard - Hay
# 1  Subset of NIBRS Assault Offenses         3     9  Midtown Phillips
# 2  Subset of NIBRS Assault Offenses         4     4          McKinley
# 3           Counterfeiting/Forgery          1     7       Elliot Park
# 4                 Assault Offenses          1     3     Downtown West
#
#         Date  Maximum Temperature degrees (F)  \
# 0 2019-01-09                             16.0
# 1 2019-01-09                             16.0
# 2 2019-01-09                             16.0
# 3 2019-01-09                             16.0
# 4 2019-01-09                             16.0
#
#    Minimum Temperature degrees (F)  Precipitation (inches)  Snow (inches)  \
# 0                              6.0                     0.0            0.0
# 1                              6.0                     0.0            0.0
# ...

# %%
df.rename(columns={'Time_To_Report_days': 'reported_in', 'Mean_Temperature_F': 'mean_temp'}).head()
# Out:
#                    Offense_Category  Precinct  Ward      Neighborhood  \
# 0  Subset of NIBRS Assault Offenses         4     5     Willard - Hay
# 1  Subset of NIBRS Assault Offenses         3     9  Midtown Phillips
# 2  Subset of NIBRS Assault Offenses         4     4          McKinley
# 3           Counterfeiting/Forgery          1     7       Elliot Park
# 4                 Assault Offenses          1     3     Downtown West
#
#         Date  Maximum Temperature degrees (F)  \
# 0 2019-01-09                             16.0
# 1 2019-01-09                             16.0
# 2 2019-01-09                             16.0
# 3 2019-01-09                             16.0
# 4 2019-01-09                             16.0
#
#    Minimum Temperature degrees (F)  Precipitation (inches)  Snow (inches)  \
# 0                              6.0                     0.0            0.0
# 1                              6.0                     0.0            0.0
# ...

# %%
crime_series=df[df["Year"]==2021].groupby('Month').count()['Ward']

# %%
# Out:
#            Offense_Category  Precinct   Ward  Neighborhood   Date  \
# Month
# April                 15073     15073  15073         15073  15073
# August                20345     20345  20345         20345  20345
# December              15411     15411  15411         15411  15411
# February              12413     12413  12413         12413  12413
# January               14671     14671  14671         14671  14671
# July                  20471     20471  20471         20471  20471
# June                  19403     19403  19403         19403  19403
# March                 14462     14462  14462         14462  14462
# May                   18819     18819  18819         18819  18819
# November              17022     17022  17022         17022  17022
# October               19429     19429  19429         19429  19429
# September             19516     19516  19516         19516  19516
#
#            Maximum Temperature degrees (F)  Minimum Temperature degrees (F)  \
# Month
# ...

# %%
import pandas as pd

# Assuming 'Month' is a column in your DataFrame
crime_series = df[df["Year"] == 2021].groupby('Month').count()['Ward']

# Convert the 'Month' column to a categorical type with custom ordering
months_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
crime_series.index = pd.Categorical(crime_series.index, categories=months_order, ordered=True)

# Sort the index (Month) in the desired order
crime_series = crime_series.sort_index()

# Print or use the sorted crime_series
# Out:
# January      3851
# February     2973
# March        3509
# April        3836
# May          4889
# June         4622
# July         4848
# August       4885
# September    5076
# October      5015
# November     4752
# December     4279
# Name: Ward, dtype: int64

# %%
temp_series=df[df["Year"]==2021].groupby('Month').mean()['Mean_Temperature_F']

# %%
import pandas as pd

# Assuming 'Month' is a column in your DataFrame
temp_series = df[df["Year"] == 2021].groupby('Month').mean()['Mean_Temperature_F']

# Convert the 'Month' column to a categorical type with custom ordering
months_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
temp_series.index = pd.Categorical(temp_series.index, categories=months_order, ordered=True)

# Sort the index (Month) in the desired order
temp_series = temp_series.sort_index()

# Print or use the sorted temp_series
print(temp_series)
# Out:
# January      22.034796
# February     12.581063
# March        40.576803
# April        47.778024
# May          61.026693
# June         76.590762
# July         76.153568
# August       73.925179
# September    66.606678
# October      56.163709
# November     37.755577
# December     24.730661
# Name: Mean_Temperature_F, dtype: float64

# %%
temp_series
# Out:
# January      22.034796
# February     12.581063
# March        40.576803
# April        47.778024
# May          61.026693
# June         76.590762
# July         76.153568
# August       73.925179
# September    66.606678
# October      56.163709
# November     37.755577
# December     24.730661
# Name: Mean_Temperature_F, dtype: float64

# %%
ht_data=pd.concat([crime_series, temp_series], axis=1)

# %%
ht_data.reset_index(inplace=True)

# %%
ht_data.head(3)
# Out:
#       month  crime_count  Mean_Temperature_F
# 0   January         3851           22.034796
# 1  February         2973           12.581063
# 2     March         3509           40.576803

# %%
ht_data.rename(columns={'index': 'month', 'Ward': 'crime_count'},inplace=True)

# %%
ht_data.head(3)
# Out:
#       month  crime_count  Mean_Temperature_F
# 0   January         3851           22.034796
# 1  February         2973           12.581063
# 2     March         3509           40.576803

# %%
ht_data.to_csv('ht_data')
